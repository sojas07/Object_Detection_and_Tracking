# %%
import cv2
import numpy as np 
import math
from ultralytics import YOLO

# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# ## **Custom Data Training**

# %%
# !pip uninstall wandb -y

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/kaggle/input/safetyconstructiondata/data/data.yaml' epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...
